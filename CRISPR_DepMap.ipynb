# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/CRISPRGeneEffect.csv')
df.head()
# Out:
#       ModelID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 0  ACH-000001 -0.102725      0.058595  0.058246       -0.041881
# 1  ACH-000004  0.008878     -0.077633 -0.099297        0.030120
# 2  ACH-000005 -0.117950      0.013989  0.164099        0.184570
# 3  ACH-000007 -0.049135     -0.089991  0.084994        0.129586
# 4  ACH-000009  0.004969     -0.098170  0.092887        0.110913
#
#    A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  AACS (65985)  \
# 0         -0.088661        0.170335      -0.015254    -0.223691      0.218612
# 1         -0.080334       -0.112404       0.298774    -0.125139      0.218675
# 2         -0.201766       -0.202198       0.207814    -0.089192     -0.082624
# 3         -0.041561       -0.014555       0.045143    -0.263324     -0.135143
# 4          0.028599       -0.087008       0.073032    -0.240147      0.072294
#
#    ...  ZWILCH (55055)  ZWINT (11130)  ZXDA (7789)  ZXDB (158586)  \
# ...

# %%
df
# Out:
#          ModelID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 0     ACH-000001 -0.102725      0.058595  0.058246       -0.041881
# 1     ACH-000004  0.008878     -0.077633 -0.099297        0.030120
# 2     ACH-000005 -0.117950      0.013989  0.164099        0.184570
# 3     ACH-000007 -0.049135     -0.089991  0.084994        0.129586
# 4     ACH-000009  0.004969     -0.098170  0.092887        0.110913
# ...          ...       ...           ...       ...             ...
# 1090  ACH-002800 -0.000591     -0.118200  0.264553        0.117171
# 1091  ACH-002834 -0.046332     -0.105593  0.072203        0.058669
# 1092  ACH-002847 -0.036301     -0.074850  0.052350        0.097964
# 1093  ACH-002922 -0.036065      0.024183  0.020325        0.265791
# 1094  ACH-002926 -0.074473     -0.071863  0.080549        0.160242
#
#       A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 0            -0.088661        0.170335      -0.015254    -0.223691
# ...

# %%
df.columns
# Out:
# Index(['ModelID', 'A1BG (1)', 'A1CF (29974)', 'A2M (2)', 'A2ML1 (144568)',
#        'A3GALT2 (127550)', 'A4GALT (53947)', 'A4GNT (51146)', 'AAAS (8086)',
#        'AACS (65985)',
#        ...
#        'ZWILCH (55055)', 'ZWINT (11130)', 'ZXDA (7789)', 'ZXDB (158586)',
#        'ZXDC (79364)', 'ZYG11A (440590)', 'ZYG11B (79699)', 'ZYX (7791)',
#        'ZZEF1 (23140)', 'ZZZ3 (26009)'],
#       dtype='object', length=17932)

# %%
df['A1BG (1)'].min()

# %%
df['A1BG (1)'].max()

# %%
df = df.dropna()

# %%
df = df.fillna(df.mean())
# Out:
# C:\Users\Panini Bhamidipati\miniconda3\envs\torch\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#          ModelID  A1BG (1)  A1CF (29974)   A2M (2)  A2ML1 (144568)  \
# 0     ACH-000001 -0.102725      0.058595  0.058246       -0.041881
# 1     ACH-000004  0.008878     -0.077633 -0.099297        0.030120
# 2     ACH-000005 -0.117950      0.013989  0.164099        0.184570
# 3     ACH-000007 -0.049135     -0.089991  0.084994        0.129586
# 4     ACH-000009  0.004969     -0.098170  0.092887        0.110913
# ...          ...       ...           ...       ...             ...
# 1090  ACH-002800 -0.000591     -0.118200  0.264553        0.117171
# 1091  ACH-002834 -0.046332     -0.105593  0.072203        0.058669
# 1092  ACH-002847 -0.036301     -0.074850  0.052350        0.097964
# 1093  ACH-002922 -0.036065      0.024183  0.020325        0.265791
# 1094  ACH-002926 -0.074473     -0.071863  0.080549        0.160242
#
#       A3GALT2 (127550)  A4GALT (53947)  A4GNT (51146)  AAAS (8086)  \
# 0            -0.088661        0.170335      -0.015254    -0.223691
# ...

# %%
import umap
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

reducer = umap.UMAP()

# %%
df_data = df.drop(['ModelID'], axis = 1)
df_data = StandardScaler().fit_transform(df_data)

# %%
df_data.shape
# Out:
# (1095, 17931)

# %%
embedding = reducer.fit_transform(df_data)
embedding.shape
# Out:
# (1095, 2)

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], color = 'green', marker = '*')
plt.gca().set_aspect('equal', 'datalim')
plt.title("UMAP projections of the entire DepMAP Dataset", fontsize = 18)
plt.show()
